# %% [raw]
# #  调用线上大模型
#
# ##  1. 调用具体模型厂商的API
#
# ###  1.1 调用deepseek官网的deepseek模型
#
# 调用大模型涉及到三个重要参数：base_url,model_name,api_key
#
# 举例1：将参数信息存储在.env配置文件中

# %%
import os

from dotenv import load_dotenv
from langchain_deepseek import ChatDeepSeek
from openai import responses

# 读取.env配置文件中的信息。相关的环境变量以.env文件中的优先
load_dotenv(override=True)
DEEPSEEK_API_KEY=os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL=os.getenv("DEEPSEEK_BASE_URL")

agent=ChatDeepSeek(
    model="deepseek-v4-flash",
    api_key=DEEPSEEK_API_KEY,
    api_base=DEEPSEEK_BASE_URL,
)

response=agent.invoke("你是谁？")
print(response)
# Out:
# content='你好！我是 DeepSeek，由深度求索公司创造的 AI 助手。我是纯文本模型，擅长回答问题、处理文档、辅助写作、编程等任务。我支持阅读链接、上传文件（图像、txt、pdf、ppt、word、excel 等），也能联网搜索（需要手动开启）。而且完全免费，上下文长度达 1M，能一次性处理像《三体》三部曲那么大体量的内容。\n\n有什么我可以帮你的吗？😊' additional_kwargs={'refusal': None, 'reasoning_content': '好的，用户问了一个很基础的自我介绍问题：“你是谁？” 这是一个简单直接的询问，我需要清晰、友好地告知用户我的身份和基本能力。\n\n用户可能刚接触我，或者想确认我的功能范围。深层需求是了解我能提供什么帮助，以及如何与我互动。所以回复应该包含身份说明、核心能力概述、关键特点（比如免费、长上下文、文件处理等），并保持开放和乐于助人的态度，最后以邀请提问结尾。\n\n想到了用问候开头，直接说明我是DeepSeek，由深度求索公司创造。然后列举主要功能，比如文本处理、文件支持、联网搜索等，突出免费和长上下文这些优势。最后表达服务意愿，鼓励用户继续提问。'} response_metadata={'token_usage': {'completion_tokens': 251, 'prompt_tokens': 6, 'total_tokens': 257, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 150, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 6}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': 'd76b5a9b-2652-47af-b8da-687708cfbfb7', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f3bba-4555-7802-989b-87042f664ff1-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 6, 'output_tokens': 251, 'total_tokens': 257, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 150}}
